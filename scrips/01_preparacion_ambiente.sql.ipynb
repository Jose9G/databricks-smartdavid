# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS smartdavid_catalog
MANAGED LOCATION 'abfss://golden@adlsmartdavid2202.dfs.core.windows.net/catalog/';

# %%
# %sql
USE CATALOG smartdavid_catalog;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS golden;
SHOW SCHEMAS IN smartdavid_catalog;

# %%
df_test = spark.read.csv(
    "abfss://bronze@adlsmartdavid2202.dfs.core.windows.net/pagos_prico2026.csv",
    header=True,
    sep=";"
)

# %%
print(f"Registros leídos: {df_test.count()}")
df_test.limit(3).display()
