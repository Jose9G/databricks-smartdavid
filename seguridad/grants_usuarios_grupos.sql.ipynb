# %%
# %sql
-- Ver usuarios registrados en el metastore
SELECT current_user();

# %%
# %sql
GRANT USE CATALOG ON CATALOG smartdavid_catalog TO `joose5573@gmail.com`;
GRANT CREATE SCHEMA ON CATALOG smartdavid_catalog TO `joose5573@gmail.com`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA smartdavid_catalog.bronze TO `joose5573@gmail.com`;
GRANT USE SCHEMA ON SCHEMA smartdavid_catalog.silver TO `joose5573@gmail.com`;
GRANT USE SCHEMA ON SCHEMA smartdavid_catalog.golden TO `joose5573@gmail.com`;
GRANT CREATE TABLE ON SCHEMA smartdavid_catalog.bronze TO `joose5573@gmail.com`;
GRANT CREATE TABLE ON SCHEMA smartdavid_catalog.silver TO `joose5573@gmail.com`;
GRANT CREATE TABLE ON SCHEMA smartdavid_catalog.golden TO `joose5573@gmail.com`;

# %%
# %sql
GRANT SELECT ON TABLE smartdavid_catalog.golden.rendimiento_colaborador TO `joose5573@gmail.com`;
GRANT SELECT ON TABLE smartdavid_catalog.golden.pagos_mensual            TO `joose5573@gmail.com`;
GRANT SELECT ON TABLE smartdavid_catalog.golden.cartera_pendiente        TO `joose5573@gmail.com`;
GRANT SELECT ON TABLE smartdavid_catalog.golden.resumen_departamento     TO `joose5573@gmail.com`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG smartdavid_catalog TO grp_analistas;
GRANT USE CATALOG ON CATALOG smartdavid_catalog TO grp_ingenieros_etl;
GRANT USE SCHEMA ON SCHEMA smartdavid_catalog.golden TO grp_analistas;
GRANT SELECT ON TABLE smartdavid_catalog.golden.rendimiento_colaborador TO grp_analistas;
GRANT SELECT ON TABLE smartdavid_catalog.golden.pagos_mensual            TO grp_analistas;
GRANT SELECT ON TABLE smartdavid_catalog.golden.cartera_pendiente        TO grp_analistas;
GRANT SELECT ON TABLE smartdavid_catalog.golden.resumen_departamento     TO grp_analistas;

# %%
# %sql
SHOW GRANTS ON TABLE smartdavid_catalog.golden.rendimiento_colaborador;

# %%
# %sql
SHOW GRANTS ON CATALOG smartdavid_catalog;
